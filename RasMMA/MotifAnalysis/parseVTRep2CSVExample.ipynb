# %% [markdown]
# ### parseVTRep2CSV Example
#
# Given a directory having virustotal's json report
# Output a CSV table of detection name (column: anti-virus engine; row: malware)

# %%
import os
import json
import pandas as pd
from numpy import nan as NaN

# %%
# input
in_directory = "C:/test/VTReport/" # your VTreport dir
in_hooklog_directory = "C:/Users/hsiao/Downloads/GitHub/MotifAnalysis/hooklogs/somoto_woj/" # a hooklog dir, or None
in_tag = "somoto_woj"
in_first_seen = True
in_save_to_subdir_firstseen = True

# output
out_tag = in_tag

# outfiles
out_csvfile = 'output/VTRepo_'+ out_tag + '.csv' # original
out_wn_csvfile = 'output/VTRepo_wn_'+ out_tag + '.csv' # winnowed

# %%
# MIKE: 20170822, hack for TXT (VT report) or hooklog
run_directory = in_hooklog_directory if in_hooklog_directory != None else in_directory

# iter the directory
file_list = next(os.walk(run_directory))[2]
hash_set = set(t.split('.')[0].split("_")[0] for t in file_list)
ext = file_list[0].split('.')[-1].lower() 

print("%d files" % len(file_list))
print("%d hashes" % len(hash_set))
print(ext)
print("save to", out_csvfile)
print("save to", out_wn_csvfile)
# Out:
# 59 files
# 23 hashes
# hooklog
# save to output/VTRepo_somoto_woj.csv
# save to output/VTRepo_wn_somoto_woj.csv

# %%
# find all anti-virus engines and corresponding detection strings

av_set = set() # set of all anti-virus engines
csv_dict = dict()

for h in hash_set:
    # open txt file and load it as json
    with open(os.path.join(in_directory, h + '.txt')) as txt_file:    
        json_report = json.load(txt_file)
        
    # create a dictionary _dict = {engine: "detection_name"}
    _dict = dict()
    for engine in json_report['scans'].keys(): 
        scan_result = json_report['scans'].get(engine)
        if scan_result.get("detected") == True:
            result = scan_result.get("result").encode('ascii', 'ignore')
            result = result.decode("ascii").replace(',', '') # special replacement for csv
            av_set.add(engine)
            
            _dict[engine] = result
    
    # if you don't need first_seen, set in_first_seen as Fasle
    if in_first_seen:
        _dict["first_seen"] = json_report['first_seen']
    
    # attach this dictioary to csv_dict = {hash: _dict}
    csv_dict[h] = _dict

# %%
df = pd.DataFrame(csv_dict).T

# %%
# You can print the df here
df.head()
#df['AVG']
# Out:
#                                                                    AVG  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...  AdInstaller.Somoto
# 31b164b4dc1d2744bf11183604572648                        Downloader.ATW
# 38fe6f891182ca08e3f6de18ea2153a6                              AdLoad.S
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...      Downloader.ATW
# 5169113d8207a5605ff57604a00c030a                        Downloader.ATW
#
#                                                                      AVware  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...  Trojan.Win32.Generic!BT
# 31b164b4dc1d2744bf11183604572648                    Trojan.Win32.Generic!BT
# 38fe6f891182ca08e3f6de18ea2153a6                    Trojan.Win32.Generic!BT
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...  Trojan.Win32.Generic!BT
# 5169113d8207a5605ff57604a00c030a                    Trojan.Win32.Generic!BT
#
#                                                                          Ad-Aware  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...   Application.Bundler.Somoto.I
# 31b164b4dc1d2744bf11183604572648                     Application.Bundler.Somoto.I
# 38fe6f891182ca08e3f6de18ea2153a6                    Application.Bundler.Somoto.AG
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...   Application.Bundler.Somoto.I
# 5169113d8207a5605ff57604a00c030a                     Application.Bundler.Somoto.I
#
#                                                                  AegisLab  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...                    NaN
# 31b164b4dc1d2744bf11183604572648                                      NaN
# 38fe6f891182ca08e3f6de18ea2153a6                    Troj.Downloader.W32!c
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...        Troj.Agent.mt2x
# 5169113d8207a5605ff57604a00c030a                                      NaN
#
#                                                         Agnitum  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...  PUA.Somoto!
# 31b164b4dc1d2744bf11183604572648                            NaN
# 38fe6f891182ca08e3f6de18ea2153a6                            NaN
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...          NaN
# 5169113d8207a5605ff57604a00c030a                            NaN
#
#                                                                             AhnLab-V3  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...                     Win-PUP/Somoto
# 31b164b4dc1d2744bf11183604572648                          Win-AppCare/Somoto.236936.B
# 38fe6f891182ca08e3f6de18ea2153a6                                     PUP/Win32.Somoto
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...  Unwanted/Win32.Somoto.N1167800769
# 5169113d8207a5605ff57604a00c030a                          Win-AppCare/Somoto.236952.E
#
#                                                    AntiVir  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...     NaN
# 31b164b4dc1d2744bf11183604572648                       NaN
# 38fe6f891182ca08e3f6de18ea2153a6                       NaN
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...     NaN
# 5169113d8207a5605ff57604a00c030a                       NaN
#
#                                                                        Antiy-AVL  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...                           NaN
# 31b164b4dc1d2744bf11183604572648                             Trojan/Win32.CF.gen
# 38fe6f891182ca08e3f6de18ea2153a6                    Trojan/Generic.ASMalwNS.2749
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...           Trojan/Win32.CF.gen
# 5169113d8207a5605ff57604a00c030a                             Trojan/Win32.CF.gen
#
#                                                                           Arcabit  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...                            NaN
# 31b164b4dc1d2744bf11183604572648                     Application.Bundler.Somoto.I
# 38fe6f891182ca08e3f6de18ea2153a6                    Application.Bundler.Somoto.AG
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...   Application.Bundler.Somoto.I
# 5169113d8207a5605ff57604a00c030a                     Application.Bundler.Somoto.I
#
#                                                                    Avast  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...   Win32:PUP-gen [PUP]
# 31b164b4dc1d2744bf11183604572648                                     NaN
# 38fe6f891182ca08e3f6de18ea2153a6                                     NaN
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...  Win32:Somoto-J [PUP]
# 5169113d8207a5605ff57604a00c030a                    Win32:Somoto-J [PUP]
#
#                                                      ...     \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...   ...
# 31b164b4dc1d2744bf11183604572648                     ...
# 38fe6f891182ca08e3f6de18ea2153a6                     ...
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...   ...
# 5169113d8207a5605ff57604a00c030a                     ...
#
#                                                                Symantec  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...      WS.Reputation.1
# 31b164b4dc1d2744bf11183604572648                    PUA.BetterInstaller
# 38fe6f891182ca08e3f6de18ea2153a6                        SAPE.Heur.A6182
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...  PUA.BetterInstaller
# 5169113d8207a5605ff57604a00c030a                           Trojan.ADH.2
#
#                                                                             Tencent  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...                              NaN
# 31b164b4dc1d2744bf11183604572648                                                NaN
# 38fe6f891182ca08e3f6de18ea2153a6                    Win32.Downloader.Bp-somato.Rkbk
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...                              NaN
# 5169113d8207a5605ff57604a00c030a                                                NaN
#
#                                                        TrendMicro  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...            NaN
# 31b164b4dc1d2744bf11183604572648                              NaN
# 38fe6f891182ca08e3f6de18ea2153a6                    ADW_TOMOS.SMN
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...  ADW_TOMOS.SMN
# 5169113d8207a5605ff57604a00c030a                    ADW_TOMOS.SMN
#
#                                                    TrendMicro-HouseCall  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...                  NaN
# 31b164b4dc1d2744bf11183604572648                                    NaN
# 38fe6f891182ca08e3f6de18ea2153a6                          ADW_TOMOS.SMN
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...        ADW_TOMOS.SMN
# 5169113d8207a5605ff57604a00c030a                          ADW_TOMOS.SMN
#
#                                                                                      VBA32  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...  Signed-AdWare.BetterInternet.SomotoLtd
# 31b164b4dc1d2744bf11183604572648                                                       NaN
# 38fe6f891182ca08e3f6de18ea2153a6                                                       NaN
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...  Signed-AdWare.BetterInternet.SomotoLtd
# 5169113d8207a5605ff57604a00c030a                    Signed-AdWare.BetterInternet.SomotoLtd
#
#                                                                       VIPRE  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...  Trojan.Win32.Generic!BT
# 31b164b4dc1d2744bf11183604572648                    Trojan.Win32.Generic!BT
# 38fe6f891182ca08e3f6de18ea2153a6                    Trojan.Win32.Generic!BT
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...  Trojan.Win32.Generic!BT
# 5169113d8207a5605ff57604a00c030a                    Trojan.Win32.Generic!BT
#
#                                                    ViRobot  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...     NaN
# 31b164b4dc1d2744bf11183604572648                       NaN
# 38fe6f891182ca08e3f6de18ea2153a6                       NaN
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...     NaN
# 5169113d8207a5605ff57604a00c030a                       NaN
#
#                                                                               Zillya  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...  Adware.BetterInternet.Win32.1234
# 31b164b4dc1d2744bf11183604572648                     Downloader.MazelCRTD.Win32.1058
# 38fe6f891182ca08e3f6de18ea2153a6                                                 NaN
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...      Adware.SomotoCRTD.Win32.1117
# 5169113d8207a5605ff57604a00c030a                                                 NaN
#
#                                                              first_seen  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...  2013-08-16 05:54:57
# 31b164b4dc1d2744bf11183604572648                    2014-03-23 03:01:57
# 38fe6f891182ca08e3f6de18ea2153a6                    2016-01-21 16:52:45
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...  2014-04-28 20:06:52
# 5169113d8207a5605ff57604a00c030a                    2014-03-27 06:10:06
#
#                                                    nProtect
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...      NaN
# 31b164b4dc1d2744bf11183604572648                        NaN
# 38fe6f891182ca08e3f6de18ea2153a6                        NaN
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...      NaN
# 5169113d8207a5605ff57604a00c030a                        NaN
#
# [5 rows x 53 columns]

# %%
# output
df.to_csv(out_csvfile)

# %% [markdown]
# #### Winnowing

# %%
# MIKE: 20170731 some hacks for winnowing

# %%
# delimiter is used for spliting tokens
import re
delimiter = '\,|!|\(|\)|\[|\]|@|:|/|\.| '

# general_string to remove
general_string = ['win32','trojan','adware','generic','application','variant','downloader','not-a-virus','downware',
                 'unwanted-program','heur','troj','bundler','antifw','riskware','optional','malware','behaveslike',
                 'kcloud','agent','trojandownloader','appl','trojware','installer','trojan-downloader','virus',
                 'backdoor','injector','malware-cryptor','dropper','cryptor','bundleapp','suspicious','antifwk',
                 'adinstaller','crypt','bundleinstaller','xpack', 'hacktool','patcher','troj_gen','grayware',
                 'software','install','click','heuristic','packed','unknown','applicunwnt','dropped','trojan-clicker',
                 'net-worm','monitoringtool','worm','tool','toolbar','eldorado','autorun','hw32', 'trojan-dropper']

# short family strings that should be kept
short_family_string = ['kdz', 'ipz', 'lmn']

import string
def is_hex(s):
    return all(c in string.hexdigits for c in s)

def tk_winnow(t):
    if len(t) <= 3 and t not in short_family_string:
        return None
    elif t in general_string:
        return None
    elif is_hex(t):
        return None
    
    return t

def VT_winnow(s):
    if s is NaN: return NaN
    
    tokens = re.split(delimiter, s.lower())
    ret_tokens = list(filter(lambda x : x if x is not False else True, [tk_winnow(t) for t in tokens]))
    return ret_tokens if len(ret_tokens) != 0 else NaN

# %%
df_nw = df.copy().applymap(VT_winnow)

# %%
df_nw.head()
# Out:
#                                                          AVG  AVware  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...  [somoto]     NaN
# 31b164b4dc1d2744bf11183604572648                         NaN     NaN
# 38fe6f891182ca08e3f6de18ea2153a6                    [adload]     NaN
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...       NaN     NaN
# 5169113d8207a5605ff57604a00c030a                         NaN     NaN
#
#                                                     Ad-Aware AegisLab  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...  [somoto]      NaN
# 31b164b4dc1d2744bf11183604572648                    [somoto]      NaN
# 38fe6f891182ca08e3f6de18ea2153a6                    [somoto]      NaN
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...  [somoto]   [mt2x]
# 5169113d8207a5605ff57604a00c030a                    [somoto]      NaN
#
#                                                      Agnitum  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...  [somoto]
# 31b164b4dc1d2744bf11183604572648                         NaN
# 38fe6f891182ca08e3f6de18ea2153a6                         NaN
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...       NaN
# 5169113d8207a5605ff57604a00c030a                         NaN
#
#                                                                           AhnLab-V3  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...                [win-pup, somoto]
# 31b164b4dc1d2744bf11183604572648                              [win-appcare, somoto]
# 38fe6f891182ca08e3f6de18ea2153a6                                           [somoto]
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...  [unwanted, somoto, n1167800769]
# 5169113d8207a5605ff57604a00c030a                              [win-appcare, somoto]
#
#                                                    AntiVir   Antiy-AVL  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...     NaN         NaN
# 31b164b4dc1d2744bf11183604572648                       NaN         NaN
# 38fe6f891182ca08e3f6de18ea2153a6                       NaN  [asmalwns]
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...     NaN         NaN
# 5169113d8207a5605ff57604a00c030a                       NaN         NaN
#
#                                                      Arcabit       Avast  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...       NaN   [pup-gen]
# 31b164b4dc1d2744bf11183604572648                    [somoto]         NaN
# 38fe6f891182ca08e3f6de18ea2153a6                    [somoto]         NaN
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...  [somoto]  [somoto-j]
# 5169113d8207a5605ff57604a00c030a                    [somoto]  [somoto-j]
#
#                                                      ...     \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...   ...
# 31b164b4dc1d2744bf11183604572648                     ...
# 38fe6f891182ca08e3f6de18ea2153a6                     ...
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...   ...
# 5169113d8207a5605ff57604a00c030a                     ...
#
#                                                              Symantec  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...       [reputation]
# 31b164b4dc1d2744bf11183604572648                    [betterinstaller]
# 38fe6f891182ca08e3f6de18ea2153a6                               [sape]
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...  [betterinstaller]
# 5169113d8207a5605ff57604a00c030a                                  NaN
#
#                                                               Tencent  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...                NaN
# 31b164b4dc1d2744bf11183604572648                                  NaN
# 38fe6f891182ca08e3f6de18ea2153a6                    [bp-somato, rkbk]
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...                NaN
# 5169113d8207a5605ff57604a00c030a                                  NaN
#
#                                                      TrendMicro  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...          NaN
# 31b164b4dc1d2744bf11183604572648                            NaN
# 38fe6f891182ca08e3f6de18ea2153a6                    [adw_tomos]
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...  [adw_tomos]
# 5169113d8207a5605ff57604a00c030a                    [adw_tomos]
#
#                                                    TrendMicro-HouseCall  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...                  NaN
# 31b164b4dc1d2744bf11183604572648                                    NaN
# 38fe6f891182ca08e3f6de18ea2153a6                            [adw_tomos]
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...          [adw_tomos]
# 5169113d8207a5605ff57604a00c030a                            [adw_tomos]
#
#                                                                                          VBA32  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...  [signed-adware, betterinternet, somotoltd]
# 31b164b4dc1d2744bf11183604572648                                                           NaN
# 38fe6f891182ca08e3f6de18ea2153a6                                                           NaN
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...  [signed-adware, betterinternet, somotoltd]
# 5169113d8207a5605ff57604a00c030a                    [signed-adware, betterinternet, somotoltd]
#
#                                                    VIPRE ViRobot  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...   NaN     NaN
# 31b164b4dc1d2744bf11183604572648                     NaN     NaN
# 38fe6f891182ca08e3f6de18ea2153a6                     NaN     NaN
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...   NaN     NaN
# 5169113d8207a5605ff57604a00c030a                     NaN     NaN
#
#                                                               Zillya  \
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...  [betterinternet]
# 31b164b4dc1d2744bf11183604572648                         [mazelcrtd]
# 38fe6f891182ca08e3f6de18ea2153a6                                 NaN
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...      [somotocrtd]
# 5169113d8207a5605ff57604a00c030a                                 NaN
#
#                                                       first_seen nProtect
# 25fbb984c2ebcd7fb69404a06ac4838a3a0e64293bb3a33...  [2013-08-16]      NaN
# 31b164b4dc1d2744bf11183604572648                    [2014-03-23]      NaN
# 38fe6f891182ca08e3f6de18ea2153a6                    [2016-01-21]      NaN
# 4f2483f23c8eae37a77fdbcf9133d38ba51f8edac4b8fb7...  [2014-04-28]      NaN
# 5169113d8207a5605ff57604a00c030a                    [2014-03-27]      NaN
#
# [5 rows x 53 columns]

# %%
# output
df_nw.to_csv(out_wn_csvfile)

# %% [markdown]
# ## Save files to new directory based on first-seen year

# %%
import shutil

#MIKE: set the interval of years 
in_years = [(0, 2000), (2001, 2010), (2011, 2014), (2015, 2017)]

def max_year(y):
    global in_years
    for min_year, max_year in in_years:
        if min_year <= y <= max_year:
            return max_year
    return -1

# %%
if in_save_to_subdir_firstseen and in_hooklog_directory and ext == "hooklog":
    first_seen_year_series = df['first_seen'].apply(lambda f: int(f.split('-')[0]))
    save_year_series = first_seen_year_series.apply(max_year)
    save_year_series.name = "save_year"
    
    for f in file_list:
        
        name = f.split('_')[0]
        save_year = save_year_series[name]
        
        new_dir = "hooklogs/" + in_tag + "_year" + str(save_year) +"/"
        if not os.path.isdir(new_dir):
            os.makedirs(new_dir)
            
        shutil.copy(os.path.join(in_hooklog_directory, f), os.path.join(new_dir, f))
        
    print("new files with year is saved to", "hooklogs/" + in_tag + "_year")
# Out:
# new files with year is saved to hooklogs/somoto_woj_year
