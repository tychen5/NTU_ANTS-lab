# %% [markdown]
# ## Global Pairwise Sequence Alignment
#
#     Given two sequnce alignment, generate a 3-tuples datastructure of alignment result.
#     output: (identity_total, residue_total, alignment result list)
#
#     * alignment result list: each element is a 2-tuples node (hk1_api, hk2_api)
#       hk1_api format -> (Ordinal number, api+par+return)
#       e.g., each element (hk1_api, hk2_api)
#       -> ((1, 'LoadLibrary#PR#SYS@imm32@DLL#PR#SUCCESS'), (1, 'LoadLibrary#PR#SYS@imm32@DLL#PR#SUCCESS'))

# %%
#global alignment (Needleman - Wunsch algorithm) 
def seqMatch(h1_list, i, h2_list, j, window):
    for w in range(0, window):
        api = h1_list[i+w]
        a = h2_list[j+w]
        if api != a:
            return 0
    return 1

def pairwise_NW(h1_list ,h2_list, dp_matched, dp_mismatched, dp_gap, isret, offset, window):
    #isret == 1 add return to list else not add
    h1_list = [(t,a[:a.rindex('#')+1]) for t,a in h1_list] if not isret else h1_list
    h2_list = [(t,a[:a.rindex('#')+1]) for t,a in h2_list] if not isret else h2_list

    isH1Long = True if len(h1_list) >= len(h2_list) else False 
    long_list = h1_list if isH1Long else h2_list
    short_list = h2_list if isH1Long else h1_list

    # calc: dynamic programming, Needleman-Wunsch algorithm, use long_list
    # ,short_list to find best local alignment # MIKE:20141023
    m = len(short_list)
    n = len(long_list)
    
    # MIKE: score matrix, all zero, dynamic programming needs one more row and col
    # NEWMAN: NW score matrix, initialization
    score = [[dp_gap*i if j==0 else 0 for j in range(n+1)] for i in range(m+1)]
    score[0] = [0+dp_gap*j for j in range(n+1)]
    
    # calc: for match 
    matched = [[0 for j in range(n+1)] for i in range(m+1)]
    for i in range(len(short_list)):
        if offset + i + window > len(short_list): break
        for j in range(len(long_list)):
            if offset + j + window > len(long_list): break
            if seqMatch(short_list, offset+i, long_list, offset+j, window):
                matched[i+1][j+1] = 1

    # dynamic programming
    highest_score = 0
    highest_xy = (0,0)
    walk = [[0 for j in range(n+1)] for i in range(m+1)]
    
    #start from 1, the first additional col/row are all zero, no need to process
    for i in range(1, m+1): 
        for j in range(1, n+1):
            # case 1: matched or mismatched
            sc_ab = 0
            if matched[i][j] == 1:
                sc_ab = score[i-1][j-1] + dp_matched
            else:
                sc_ab = score[i-1][j-1] + dp_mismatched

            # case 2: gap y
            max_y = -100000             #===== 0->-10000
            for wy in range(1,j): # 1~j-1
                test = score[i][wy] + (j-wy) * dp_gap
                max_y = test if test > max_y else max_y

            # case 3: gap x
            max_x = -100000             #===== 0->-10000
            for wx in range(1,i):
                test = score[wx][j] + (i-wx) * dp_gap
                max_x = test if test > max_x else max_x

            # record path
            if max_x > max_y:
                walk[i][j] = '=' if sc_ab >= max_x else 'x'
                score[i][j] = sc_ab if sc_ab >= max_x else max_x
            else:
                walk[i][j] = '=' if sc_ab >= max_y else 'y'
                score[i][j] = sc_ab if sc_ab >= max_y else max_y
            
            # record max 
            if score[i][j] > highest_score:
                highest_score = score[i][j]
                highest_xy = (i,j)
            
    #NEWMAN: NW walk matrix, correction on 1st row and 1st column
    walk[0] = ['y' for j in range(n+1)]
    walk = [ ['x' if j==0 else walk[i][j] for j in range(n+1)] for i in range(m+1)]
                
    #alignment gap insertion 
    ali_short =[]
    ali_long=[]
    while 1:
        if walk[m][n] == '=':
            ali_short.append((m,short_list[m-1]))
            ali_long.append((n,long_list[n-1]))
            m=m-1
            n=n-1
        elif walk[m][n] == 'x':
            ali_short.append((m,short_list[m-1]))
            ali_long.append((-1,'='))
            m=m-1
        else:
            ali_short.append((-1,'='))
            ali_long.append((n,long_list[n-1]))
            n=n-1
        if m==0 and n==0:
            break
            
    long_list = h1_list if isH1Long else h2_list
    ali_result = list(zip(ali_long,ali_short)) if isH1Long else list(zip(ali_short,ali_long))
    ali_result = ali_result[::-1]
    
    #distance measure
    residue_total = 0
    identity_total = 0
    for i,j in ali_result:
        if i==(-1,'=') or j==(-1,'='):
            pass
        else:
            residue_total+=1
            if i==j: 
                identity_total+=1
    
    return identity_total, residue_total, ali_result

# %% [markdown]
# ### Example

# %%
# %run "FeatureHooklog.ipynb"
testDir = "test/hooklogs/"
base = testDir + "ffe9afc0f1344eb2ee6b1c391445bdd0_3152.trace.hooklog"
hk = testDir + "ffe83caf42822dd3c1a3690db5caf740_3156.trace.hooklog"
fp_base = FeatureHooklog(base, 0).getHkli_noContainTS()
fp_hk = FeatureHooklog(hk, 0).getHkli_noContainTS()

# pairwise_NW(h1_list ,h2_list, dp_matched, dp_mismatched, dp_gap, isret, offset, window)
pw = pairwise_NW( fp_base, fp_hk, 2, -1, -3, 1, 0, 1)

print ('identity_total:', pw[0])
print ('residue_total:', pw[1])
print ('alingment result:')
for i, apiPair in enumerate(pw[2]):
    print (i, apiPair)
# Out:
# identity_total: 242
# residue_total: 248
# alingment result:
# 0 ((1, 'LoadLibrary#PR#SYS@imm32@DLL#PR#SUCCESS'), (1, 'LoadLibrary#PR#SYS@imm32@DLL#PR#SUCCESS'))
# 1 ((2, 'LoadLibrary#PR#SYS@lpk@DLL#PR#SUCCESS'), (2, 'LoadLibrary#PR#SYS@lpk@DLL#PR#SUCCESS'))
# 2 ((3, 'LoadLibrary#PR#SYS@gdi32@DLL#PR#SUCCESS'), (3, 'LoadLibrary#PR#SYS@gdi32@DLL#PR#SUCCESS'))
# 3 ((4, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'), (4, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'))
# 4 ((5, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'), (5, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'))
# 5 ((6, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'), (6, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'))
# 6 ((7, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'), (7, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'))
# 7 ((8, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'), (8, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'))
# 8 ((9, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'), (9, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'))
# 9 ((10, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'), (10, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'))
# 10 ((11, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'), (11, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'))
# 11 ((12, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'), (12, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'))
# 12 ((13, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'), (13, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'))
# 13 ((14, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'), (14, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'))
# 14 ((15, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'), (15, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'))
# 15 ((16, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'), (16, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'))
# 16 ((17, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'), (17, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'))
# 17 ((18, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'), (18, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'))
# 18 ((19, 'LoadLibrary#PR#SYS@mapi@DLL#PR#FAILURE'), (19, 'LoadLibrary#PR#SYS@mapi@DLL#PR#FAILURE'))
# 19 ((20, 'LoadLibrary#PR#SYS@mapi@DLL#PR#FAILURE'), (20, 'LoadLibrary#PR#SYS@mapi@DLL#PR#FAILURE'))
# 20 ((21, 'LoadLibrary#PR#SYS@mapi@DLL#PR#FAILURE'), (21, 'LoadLibrary#PR#SYS@mapi@DLL#PR#FAILURE'))
# 21 ((22, 'LoadLibrary#PR#SYS@mapi@DLL#PR#FAILURE'), (22, 'LoadLibrary#PR#SYS@mapi@DLL#PR#FAILURE'))
# 22 ((23, 'LoadLibrary#PR#SYS@mapi@DLL#PR#FAILURE'), (23, 'LoadLibrary#PR#SYS@mapi@DLL#PR#FAILURE'))
# 23 ((24, 'LoadLibrary#PR#SYS@user32@DLL#PR#SUCCESS'), (24, 'LoadLibrary#PR#SYS@user32@DLL#PR#SUCCESS'))
# 24 ((25, 'LoadLibrary#PR#SYS@user32@DLL#PR#SUCCESS'), (25, 'LoadLibrary#PR#SYS@user32@DLL#PR#SUCCESS'))
# 25 ((26, 'LoadLibrary#PR#SYS@user32@DLL#PR#SUCCESS'), (26, 'LoadLibrary#PR#SYS@user32@DLL#PR#SUCCESS'))
# 26 ((27, 'LoadLibrary#PR#SYS@user32@DLL#PR#SUCCESS'), (27, 'LoadLibrary#PR#SYS@user32@DLL#PR#SUCCESS'))
# 27 ((28, 'LoadLibrary#PR#SYS@user32@DLL#PR#SUCCESS'), (28, 'LoadLibrary#PR#SYS@user32@DLL#PR#SUCCESS'))
# 28 ((29, 'LoadLibrary#PR#SYS@user32@DLL#PR#SUCCESS'), (29, 'LoadLibrary#PR#SYS@user32@DLL#PR#SUCCESS'))
# 29 ((30, 'LoadLibrary#PR#SYS@user32@DLL#PR#SUCCESS'), (30, 'LoadLibrary#PR#SYS@user32@DLL#PR#SUCCESS'))
# 30 ((31, 'LoadLibrary#PR#SYS@user32@DLL#PR#SUCCESS'), (31, 'LoadLibrary#PR#SYS@user32@DLL#PR#SUCCESS'))
# 31 ((32, 'LoadLibrary#PR#SYS@user32@DLL#PR#SUCCESS'), (32, 'LoadLibrary#PR#SYS@user32@DLL#PR#SUCCESS'))
# 32 ((33, 'LoadLibrary#PR#SYS@user32@DLL#PR#SUCCESS'), (33, 'LoadLibrary#PR#SYS@user32@DLL#PR#SUCCESS'))
# 33 ((34, 'LoadLibrary#PR#SYS@user32@DLL#PR#SUCCESS'), (34, 'LoadLibrary#PR#SYS@user32@DLL#PR#SUCCESS'))
# 34 ((35, 'LoadLibrary#PR#SYS@shlwapi@DLL#PR#SUCCESS'), (35, 'LoadLibrary#PR#SYS@shlwapi@DLL#PR#SUCCESS'))
# 35 ((36, 'LoadLibrary#PR#SYS@wininet@DLL#PR#SUCCESS'), (36, 'LoadLibrary#PR#SYS@wininet@DLL#PR#SUCCESS'))
# 36 ((37, 'LoadLibrary#PR#SYS@advapi32@DLL#PR#SUCCESS'), (37, 'LoadLibrary#PR#SYS@advapi32@DLL#PR#SUCCESS'))
# 37 ((38, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'), (38, 'LoadLibrary#PR#SYS@kernel32@DLL#PR#SUCCESS'))
# 38 ((39, 'LoadLibrary#PR#SYS@advapi32@DLL#PR#SUCCESS'), (39, 'LoadLibrary#PR#SYS@advapi32@DLL#PR#SUCCESS'))
# 39 ((40, 'RegQueryValue#PR#HKLM@sys_curCtlSet_ctl_sessionManager\\*#PR#0'), (40, 'RegQueryValue#PR#HKLM@sys_curCtlSet_ctl_sessionManager\\*#PR#0'))
# 40 ((41, 'RegQueryValue#PR#HKLM@soft_ms_ole\\*#PR#2'), (41, 'RegQueryValue#PR#HKLM@soft_ms_ole\\*#PR#2'))
# 41 ((42, 'LoadLibrary#PR#SYS@comctl32@DLL#PR#SUCCESS'), (42, 'LoadLibrary#PR#SYS@comctl32@DLL#PR#SUCCESS'))
# 42 ((43, 'CreateFile#PR#ARB@MANIFEST&&dA:GENERIC_READ#PR#SUCCESS'), (43, 'CreateFile#PR#ARB@MANIFEST&&dA:GENERIC_READ#PR#SUCCESS'))
# 43 ((44, 'RegQueryValue#PR#HKCU@desktop\\smoothscroll#PR#2'), (44, 'RegQueryValue#PR#HKCU@desktop\\smoothscroll#PR#2'))
# 44 ((45, 'RegQueryValue#PR#HKCU@soft_ms_win_explorer\\advanced\\enableballoontips#PR#2'), (45, 'RegQueryValue#PR#HKCU@soft_ms_win_explorer\\advanced\\enableballoontips#PR#2'))
# 45 ((46, 'RegEnumValue#PR#HKLM@soft_ms_winNT_languagepack\\*#PR#0'), (46, 'RegEnumValue#PR#HKLM@soft_ms_winNT_languagepack\\*#PR#0'))
# 46 ((47, 'RegCreateKey#PR#HKCU@software\\microsoft\\windows\\currentversion\\internet settings#PR#0'), (47, 'RegCreateKey#PR#HKCU@software\\microsoft\\windows\\currentversion\\internet settings#PR#0'))
# 47 ((48, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (48, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 48 ((49, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (49, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 49 ((50, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (50, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 50 ((51, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (51, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 51 ((52, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (52, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 52 ((53, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (53, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 53 ((54, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (54, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 54 ((55, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (55, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 55 ((56, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (56, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 56 ((57, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (57, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 57 ((58, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (58, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 58 ((59, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (59, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 59 ((60, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (60, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 60 ((61, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (61, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 61 ((62, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (62, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 62 ((63, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (63, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 63 ((64, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (64, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 64 ((65, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (65, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 65 ((66, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (66, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 66 ((67, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (67, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 67 ((68, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (68, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 68 ((69, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (69, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 69 ((70, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (70, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 70 ((71, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (71, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 71 ((72, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (72, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 72 ((73, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (73, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 73 ((74, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (74, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 74 ((75, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (75, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 75 ((76, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (76, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 76 ((77, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (77, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 77 ((78, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (78, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 78 ((79, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (79, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 79 ((80, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (80, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 80 ((81, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (81, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 81 ((82, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (82, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 82 ((83, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (83, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 83 ((84, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (84, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 84 ((85, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (85, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 85 ((86, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (86, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 86 ((87, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (87, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 87 ((88, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (88, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 88 ((89, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (89, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 89 ((90, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (90, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 90 ((91, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (91, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 91 ((92, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (92, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 92 ((93, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (93, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 93 ((94, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (94, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 94 ((95, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (95, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 95 ((96, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (96, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 96 ((97, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (97, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 97 ((98, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (98, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 98 ((99, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (99, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 99 ((100, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (100, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 100 ((101, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (101, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 101 ((102, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (102, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 102 ((103, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (103, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 103 ((104, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (104, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 104 ((105, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (105, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 105 ((106, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (106, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 106 ((107, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (107, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 107 ((108, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (108, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 108 ((109, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (109, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 109 ((110, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (110, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 110 ((111, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (111, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 111 ((112, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (112, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 112 ((113, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (113, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 113 ((114, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (114, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 114 ((115, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (115, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 115 ((116, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (116, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 116 ((117, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (117, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 117 ((118, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (118, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 118 ((119, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (119, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 119 ((120, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (120, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 120 ((121, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (121, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 121 ((122, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (122, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 122 ((123, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (123, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 123 ((124, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (124, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 124 ((125, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (125, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 125 ((126, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (126, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 126 ((127, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (127, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 127 ((128, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (128, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 128 ((129, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (129, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 129 ((130, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (130, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 130 ((131, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (131, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 131 ((132, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (132, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 132 ((133, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (133, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 133 ((134, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (134, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 134 ((135, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (135, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 135 ((136, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (136, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 136 ((137, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (137, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 137 ((138, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (138, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 138 ((139, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (139, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 139 ((140, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (140, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 140 ((141, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (141, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 141 ((142, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (142, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 142 ((143, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (143, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 143 ((144, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (144, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 144 ((145, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (145, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 145 ((146, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'), (146, 'CreateFile#PR#USR@EXE&&dA:GENERIC_READ#PR#SUCCESS'))
# 146 ((147, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'), (147, 'CopyFile#PR#C:\\Documents and Settings\\All Users\\Desktop\\malware.exe#PR#SUCCESS'))
# 147 ((148, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (148, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 148 ((149, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (149, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 149 ((150, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (150, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 150 ((151, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (151, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 151 ((152, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (152, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 152 ((153, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (153, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 153 ((154, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (154, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 154 ((155, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (155, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 155 ((156, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (156, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 156 ((157, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (157, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 157 ((158, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (158, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 158 ((159, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (159, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 159 ((160, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (160, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 160 ((161, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (161, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 161 ((162, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (162, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 162 ((163, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (163, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 163 ((164, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (164, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 164 ((165, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (165, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 165 ((166, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (166, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 166 ((167, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (167, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 167 ((168, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (168, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 168 ((169, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (169, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 169 ((170, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (170, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 170 ((171, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (171, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 171 ((172, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (172, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 172 ((173, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (173, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 173 ((174, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (174, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 174 ((175, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (175, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 175 ((176, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (176, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 176 ((177, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (177, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 177 ((178, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (178, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 178 ((179, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (179, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 179 ((180, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (180, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 180 ((181, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (181, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 181 ((182, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (182, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 182 ((183, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (183, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 183 ((184, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (184, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 184 ((185, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (185, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 185 ((186, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (186, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 186 ((187, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (187, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 187 ((188, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (188, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 188 ((189, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (189, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 189 ((190, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (190, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 190 ((191, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (191, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 191 ((192, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (192, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 192 ((193, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (193, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 193 ((194, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (194, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 194 ((195, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (195, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 195 ((196, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (196, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 196 ((197, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (197, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 197 ((198, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (198, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 198 ((199, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (199, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 199 ((200, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (200, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 200 ((201, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (201, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 201 ((202, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (202, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 202 ((203, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (203, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 203 ((204, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (204, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 204 ((205, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (205, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 205 ((206, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (206, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 206 ((207, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (207, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 207 ((208, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (208, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 208 ((209, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (209, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 209 ((210, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (210, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 210 ((211, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (211, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 211 ((212, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (212, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 212 ((213, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (213, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 213 ((214, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (214, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 214 ((215, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (215, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 215 ((216, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (216, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 216 ((217, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (217, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 217 ((218, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (218, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 218 ((219, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (219, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 219 ((220, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (220, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 220 ((221, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (221, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 221 ((222, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (222, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 222 ((223, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (223, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 223 ((224, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (224, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 224 ((225, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (225, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 225 ((226, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (226, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 226 ((227, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (227, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 227 ((228, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (228, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 228 ((229, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (229, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 229 ((230, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (230, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 230 ((231, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (231, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 231 ((232, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (232, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 232 ((233, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (233, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 233 ((234, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (234, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 234 ((235, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (235, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 235 ((236, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (236, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 236 ((237, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (237, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 237 ((238, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (238, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 238 ((239, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (239, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 239 ((240, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (240, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 240 ((241, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (241, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 241 ((242, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (242, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 242 ((243, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (243, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 243 ((244, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (244, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 244 ((245, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (245, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 245 ((246, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (246, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 246 ((247, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'), (247, 'CreateFile#PR#ARB@EXE&&dA:GENERIC_READ;GENERIC_WRITE#PR#SUCCESS'))
# 247 ((248, 'ExitProcess#PR##PR#'), (248, 'ExitProcess#PR##PR#'))
