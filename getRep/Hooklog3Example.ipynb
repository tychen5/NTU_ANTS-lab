# %% [markdown]
# ### Hooklog3 Example
# Change the following section, if different class is used.

# %%
# if using Hooklog3
# %run Hooklog3.ipynb
Hooklog = Hooklog3

# elis using NestedHooklog3
#%run NestedHooklog3.ipynb
#Hooklog = NestedHooklog3

# elis using FeatureHooklog3
#%run FeatureHooklog3.ipynb
#Hooklog = FeatureHooklog3

# elis using NestedFeatureHooklog3
#%run NestedFeatureHooklog3.ipynb
#Hooklog = NestedFeatureHooklog3

# %%
# input 
in_directory = "C:/Users/hsiao/Dropbox/notebook/MotifAnalysis/hooklogs/morstar_f_g_56/" # make sure the last character is '/'
#in_tag = "morstar"
in_tag = in_directory.split("/")[-2]
in_parseFirstPar = False
in_window = 1

# output
out_hl_list = None
out_tag = in_tag

# outfile
out_csvfile = 'output/hl_list_'+ out_tag + '.csv'
out_featuretabfile = 'output/featurecsvfile_'+ out_tag + '.tab'
out_picklefile = 'pickle/hl_list_'+ out_tag + '.pickle'
out_apifreq_pk = 'pickle/apifreq_dict_'+ out_tag + '.pickle'

# %%
# Example
import os

hl_list = next(os.walk(in_directory))[2] # get all filenames in the in_directory
hl_list = [os.path.join(in_directory, f) for f in hl_list] # filepathname list

hl_list = list(filter(lambda f: f.endswith(".hooklog"), hl_list)) # in case some non-hooklog file in the folder

for file in hl_list:
    hl3 = Hooklog(file, in_parseFirstPar)

# %%
# Test

# print last hl3
print("=====")
print(hl3)

# get the api call sequence of last hk3
#print("=====")
#for time, api in hl3.li:
#    print(time, api)

# print each item
for i in hl3.li:
    print(i)

#print("=====")
# get the api call set of last hk3 with window size
#for api in hl3.getWinSet(in_window):
#    print(api)
# Out:
# =====
# class Hooklog3, C:/Users/hsiao/Dropbox/notebook/MotifAnalysis/hooklogs/morstar_f_g_56/f9449d87262a5016f0993d99_1948.trace.hooklog, par = 0, len = 1214, digit name = f9449d-1948
# ('357910000', 'CreateFile')
# ('358220000', 'RegQueryValue')
# ('358250000', 'RegQueryValue')
# ('358570000', 'RegQueryValue')
# ('358900000', 'LoadLibrary')
# ('358980000', 'LoadLibrary')
# ('359260000', 'RegQueryValue')
# ('359270000', 'RegQueryValue')
# ('360730000', 'LoadLibrary')
# ('360890000', 'RegQueryValue')
# ('360970000', 'RegQueryValue')
# ('360980000', 'RegQueryValue')
# ('360980000', 'RegQueryValue')
# ('360990000', 'RegQueryValue')
# ('360990000', 'RegQueryValue')
# ('361000000', 'RegQueryValue')
# ('361000000', 'RegQueryValue')
# ('361010000', 'RegQueryValue')
# ('361010000', 'RegQueryValue')
# ('361020000', 'RegQueryValue')
# ('361020000', 'RegQueryValue')
# ('361030000', 'RegQueryValue')
# ('361040000', 'RegQueryValue')
# ('361040000', 'RegQueryValue')
# ('361050000', 'RegQueryValue')
# ('361050000', 'RegQueryValue')
# ('361050000', 'RegQueryValue')
# ('361060000', 'RegQueryValue')
# ('361060000', 'RegQueryValue')
# ('361060000', 'RegQueryValue')
# ('361090000', 'RegQueryValue')
# ('361100000', 'RegQueryValue')
# ('361110000', 'RegQueryValue')
# ('361110000', 'RegQueryValue')
# ('363710000', 'LoadLibrary')
# ('364630000', 'LoadLibrary')
# ('365100000', 'LoadLibrary')
# ('367310000', 'LoadLibrary')
# ('367490000', 'RegCreateKey')
# ('383460000', 'LoadLibrary')
# ('383850000', 'LoadLibrary')
# ('383890000', 'LoadLibrary')
# ('383920000', 'LoadLibrary')
# ('383930000', 'LoadLibrary')
# ('384110000', 'LoadLibrary')
# ('384170000', 'LoadLibrary')
# ('384190000', 'LoadLibrary')
# ('384210000', 'LoadLibrary')
# ('384230000', 'LoadLibrary')
# ('384270000', 'LoadLibrary')
# ('384290000', 'LoadLibrary')
# ('384590000', 'LoadLibrary')
# ('384610000', 'LoadLibrary')
# ('384650000', 'LoadLibrary')
# ('384710000', 'LoadLibrary')
# ('385670000', 'RegQueryValue')
# ('385700000', 'RegQueryValue')
# ('385720000', 'LoadLibrary')
# ('387800000', 'RegQueryValue')
# ('387800000', 'RegEnumValue')
# ('387810000', 'RegEnumValue')
# ('387820000', 'RegEnumValue')
# ('387860000', 'RegEnumValue')
# ('388420000', 'RegQueryValue')
# ('388420000', 'RegQueryValue')
# ('388420000', 'RegQueryValue')
# ('388420000', 'RegQueryValue')
# ('388420000', 'RegQueryValue')
# ('388420000', 'RegQueryValue')
# ('389000000', 'RegQueryValue')
# ('389770000', 'RegQueryValue')
# ('389840000', 'LoadLibrary')
# ('390320000', 'RegQueryValue')
# ('390560000', 'CreateFile')
# ('390690000', 'RegQueryValue')
# ('390690000', 'LoadLibrary')
# ('391470000', 'RegQueryValue')
# ('391470000', 'RegQueryValue')
# ('391510000', 'RegQueryValue')
# ('391510000', 'LoadLibrary')
# ('391970000', 'RegQueryValue')
# ('392050000', 'CreateFile')
# ('392370000', 'RegQueryValue')
# ('392490000', 'RegQueryValue')
# ('392560000', 'RegQueryValue')
# ('392640000', 'RegQueryValue')
# ('392700000', 'RegQueryValue')
# ('393810000', 'RegCreateKey')
# ('393820000', 'RegQueryValue')
# ('393820000', 'RegQueryValue')
# ('393830000', 'RegCreateKey')
# ('393830000', 'RegQueryValue')
# ('393830000', 'RegQueryValue')
# ('393840000', 'RegCreateKey')
# ('393840000', 'RegQueryValue')
# ('393840000', 'RegQueryValue')
# ('394110000', 'LoadLibrary')
# ('394350000', 'RegQueryValue')
# ('394390000', 'RegQueryValue')
# ('394610000', 'RegQueryValue')
# ('394700000', 'RegQueryValue')
# ('394720000', 'RegQueryValue')
# ('395210000', 'LoadLibrary')
# ('395370000', 'LoadLibrary')
# ('396170000', 'RegQueryValue')
# ('396220000', 'RegQueryValue')
# ('396250000', 'RegQueryValue')
# ('396350000', 'RegQueryValue')
# ('396440000', 'RegQueryValue')
# ('396540000', 'RegQueryValue')
# ('396660000', 'RegQueryValue')
# ('397760000', 'CreateFile')
# ('398300000', 'RegQueryValue')
# ('399040000', 'RegQueryValue')
# ('399070000', 'RegQueryValue')
# ('399100000', 'RegQueryValue')
# ('399190000', 'RegQueryValue')
# ('399260000', 'RegQueryValue')
# ('399380000', 'RegQueryValue')
# ('399490000', 'RegQueryValue')
# ('402000000', 'RegCreateKey')
# ('402030000', 'RegQueryValue')
# ('402040000', 'RegQueryValue')
# ('402040000', 'RegQueryValue')
# ('402040000', 'RegQueryValue')
# ('402040000', 'RegQueryValue')
# ('402050000', 'RegQueryValue')
# ('402050000', 'RegQueryValue')
# ('402050000', 'RegQueryValue')
# ('402050000', 'RegQueryValue')
# ('402050000', 'RegQueryValue')
# ('402060000', 'RegQueryValue')
# ('402060000', 'RegQueryValue')
# ('402090000', 'RegQueryValue')
# ('402090000', 'RegQueryValue')
# ('402100000', 'RegQueryValue')
# ('402100000', 'RegQueryValue')
# ('402100000', 'RegQueryValue')
# ('402100000', 'RegQueryValue')
# ('402110000', 'RegQueryValue')
# ('402110000', 'RegQueryValue')
# ('402110000', 'RegQueryValue')
# ('402110000', 'RegQueryValue')
# ('402110000', 'RegQueryValue')
# ('402120000', 'RegQueryValue')
# ('402120000', 'RegQueryValue')
# ('402120000', 'RegQueryValue')
# ('402160000', 'RegQueryValue')
# ('402160000', 'RegQueryValue')
# ('402160000', 'RegQueryValue')
# ('402160000', 'RegQueryValue')
# ('402170000', 'RegQueryValue')
# ('402170000', 'RegQueryValue')
# ('402170000', 'RegQueryValue')
# ('402170000', 'RegQueryValue')
# ('402180000', 'RegQueryValue')
# ('402180000', 'RegQueryValue')
# ('402180000', 'RegQueryValue')
# ('402180000', 'RegQueryValue')
# ('402180000', 'RegQueryValue')
# ('402220000', 'RegQueryValue')
# ('402220000', 'RegQueryValue')
# ('402220000', 'RegQueryValue')
# ('402230000', 'RegQueryValue')
# ('402230000', 'RegQueryValue')
# ('402230000', 'RegQueryValue')
# ('402240000', 'RegQueryValue')
# ('402240000', 'RegQueryValue')
# ('402250000', 'RegQueryValue')
# ('402370000', 'RegQueryValue')
# ('402400000', 'RegQueryValue')
# ('402440000', 'RegQueryValue')
# ('402440000', 'RegQueryValue')
# ('402440000', 'RegQueryValue')
# ('402440000', 'RegQueryValue')
# ('403040000', 'RegQueryValue')
# ('403120000', 'RegQueryValue')
# ('403190000', 'RegQueryValue')
# ('403390000', 'RegQueryValue')
# ('403490000', 'RegQueryValue')
# ('403600000', 'RegQueryValue')
# ('403720000', 'RegQueryValue')
# ('403860000', 'RegQueryValue')
# ('403980000', 'RegQueryValue')
# ('407080000', 'RegQueryValue')
# ('407080000', 'RegQueryValue')
# ('407090000', 'RegQueryValue')
# ('407090000', 'RegQueryValue')
# ('407100000', 'RegQueryValue')
# ('407100000', 'RegQueryValue')
# ('407140000', 'RegQueryValue')
# ('407170000', 'RegQueryValue')
# ('407170000', 'RegQueryValue')
# ('407170000', 'RegQueryValue')
# ('407180000', 'RegQueryValue')
# ('407190000', 'RegQueryValue')
# ('407190000', 'RegQueryValue')
# ('407200000', 'LoadLibrary')
# ('407260000', 'RegQueryValue')
# ('407280000', 'RegQueryValue')
# ('407280000', 'RegQueryValue')
# ('407320000', 'RegQueryValue')
# ('407340000', 'RegQueryValue')
# ('407340000', 'RegQueryValue')
# ('407350000', 'RegQueryValue')
# ('407350000', 'RegQueryValue')
# ('407360000', 'RegQueryValue')
# ('407370000', 'RegQueryValue')
# ('407370000', 'LoadLibrary')
# ('407420000', 'RegCreateKey')
# ('407420000', 'RegQueryValue')
# ('407470000', 'RegCreateKey')
# ('407480000', 'RegSetValue')
# ('407720000', 'RegQueryValue')
# ('407730000', 'RegQueryValue')
# ('407780000', 'RegSetValue')
# ('407780000', 'RegSetValue')
# ('407780000', 'RegSetValue')
# ('407810000', 'RegSetValue')
# ('407820000', 'RegSetValue')
# ('407830000', 'RegSetValue')
# ('407830000', 'RegSetValue')
# ('407830000', 'RegSetValue')
# ('407850000', 'RegSetValue')
# ('407850000', 'RegSetValue')
# ('407860000', 'RegQueryValue')
# ('407870000', 'RegQueryValue')
# ('407880000', 'RegCreateKey')
# ('407880000', 'RegQueryValue')
# ('407900000', 'RegCreateKey')
# ('407910000', 'RegSetValue')
# ('407930000', 'RegQueryValue')
# ('407930000', 'RegQueryValue')
# ('407940000', 'RegQueryValue')
# ('407950000', 'RegQueryValue')
# ('407960000', 'RegCreateKey')
# ('407970000', 'RegQueryValue')
# ('408010000', 'RegCreateKey')
# ('408010000', 'RegSetValue')
# ('408070000', 'RegQueryValue')
# ('408070000', 'RegQueryValue')
# ('408240000', 'CreateFile')
# ('408240000', 'CreateFile')
# ('408270000', 'CreateFile')
# ('408270000', 'CreateFile')
# ('413680000', 'CreateFile')
# ('413690000', 'CreateFile')
# ('413720000', 'CreateFile')
# ('413720000', 'CreateFile')
# ('419170000', 'CreateFile')
# ('419170000', 'CreateFile')
# ('419190000', 'CreateFile')
# ('419190000', 'CreateFile')
# ('424610000', 'RegQueryValue')
# ('424610000', 'RegQueryValue')
# ('424620000', 'RegQueryValue')
# ('424630000', 'RegQueryValue')
# ('424630000', 'RegQueryValue')
# ('424650000', 'RegQueryValue')
# ('424650000', 'RegQueryValue')
# ('424670000', 'RegQueryValue')
# ('424670000', 'RegQueryValue')
# ('424670000', 'RegQueryValue')
# ('424890000', 'RegQueryValue')
# ('424890000', 'RegQueryValue')
# ('424900000', 'RegQueryValue')
# ('424900000', 'RegQueryValue')
# ('424900000', 'RegQueryValue')
# ('424900000', 'RegQueryValue')
# ('424910000', 'RegQueryValue')
# ('424910000', 'RegQueryValue')
# ('424910000', 'RegQueryValue')
# ('424910000', 'RegQueryValue')
# ('424920000', 'RegQueryValue')
# ('424920000', 'RegQueryValue')
# ('424920000', 'RegQueryValue')
# ('424930000', 'RegQueryValue')
# ('424970000', 'RegQueryValue')
# ('425040000', 'RegQueryValue')
# ('425040000', 'RegQueryValue')
# ('425380000', 'RegQueryValue')
# ('425380000', 'RegQueryValue')
# ('425380000', 'RegQueryValue')
# ('425380000', 'RegQueryValue')
# ('425390000', 'RegQueryValue')
# ('425390000', 'RegQueryValue')
# ('425390000', 'RegQueryValue')
# ('425410000', 'RegQueryValue')
# ('425410000', 'RegQueryValue')
# ('425420000', 'RegQueryValue')
# ('425420000', 'RegQueryValue')
# ('425420000', 'RegQueryValue')
# ('425420000', 'RegQueryValue')
# ('425430000', 'RegQueryValue')
# ('425440000', 'RegQueryValue')
# ('425450000', 'RegQueryValue')
# ('425450000', 'RegQueryValue')
# ('425460000', 'RegQueryValue')
# ('425470000', 'RegQueryValue')
# ('425480000', 'RegQueryValue')
# ('425490000', 'RegQueryValue')
# ('425500000', 'RegQueryValue')
# ('425510000', 'RegQueryValue')
# ('425510000', 'RegQueryValue')
# ('425530000', 'RegQueryValue')
# ('425540000', 'RegQueryValue')
# ('425550000', 'RegQueryValue')
# ('425550000', 'RegQueryValue')
# ('425550000', 'RegQueryValue')
# ('425560000', 'RegQueryValue')
# ('425560000', 'RegQueryValue')
# ('425570000', 'RegQueryValue')
# ('425590000', 'RegQueryValue')
# ('425590000', 'RegQueryValue')
# ('425590000', 'RegQueryValue')
# ('425590000', 'RegQueryValue')
# ('425600000', 'RegQueryValue')
# ('425600000', 'RegQueryValue')
# ('425600000', 'RegQueryValue')
# ('425600000', 'RegQueryValue')
# ('425610000', 'RegQueryValue')
# ('425610000', 'RegQueryValue')
# ('425610000', 'RegQueryValue')
# ('425610000', 'RegQueryValue')
# ('425620000', 'RegQueryValue')
# ('425650000', 'RegQueryValue')
# ('425700000', 'RegQueryValue')
# ('425710000', 'RegQueryValue')
# ('425720000', 'RegQueryValue')
# ('426360000', 'LoadLibrary')
# ('427350000', 'RegQueryValue')
# ('427350000', 'LoadLibrary')
# ('428250000', 'RegQueryValue')
# ('428250000', 'LoadLibrary')
# ('428800000', 'RegQueryValue')
# ('428830000', 'RegQueryValue')
# ('429050000', 'RegQueryValue')
# ('429170000', 'RegQueryValue')
# ('429280000', 'RegQueryValue')
# ('429360000', 'RegQueryValue')
# ('431970000', 'RegQueryValue')
# ('432130000', 'LoadLibrary')
# ('432260000', 'LoadLibrary')
# ('433350000', 'LoadLibrary')
# ('433740000', 'LoadLibrary')
# ('433980000', 'RegQueryValue')
# ('434110000', 'RegQueryValue')
# ('434150000', 'RegQueryValue')
# ('434190000', 'RegQueryValue')
# ('434240000', 'RegQueryValue')
# ('434310000', 'RegCreateKey')
# ('434310000', 'RegCreateKey')
# ('434310000', 'RegQueryValue')
# ('434480000', 'LoadLibrary')
# ('434530000', 'LoadLibrary')
# ('434570000', 'LoadLibrary')
# ('434660000', 'LoadLibrary')
# ('434690000', 'RegQueryValue')
# ('434690000', 'LoadLibrary')
# ('434740000', 'LoadLibrary')
# ('434920000', 'LoadLibrary')
# ('435080000', 'RegQueryValue')
# ('435110000', 'RegQueryValue')
# ('435190000', 'RegQueryValue')
# ('435260000', 'RegQueryValue')
# ('435360000', 'RegQueryValue')
# ('435440000', 'RegQueryValue')
# ('435600000', 'LoadLibrary')
# ('435620000', 'LoadLibrary')
# ('436080000', 'RegQueryValue')
# ('436390000', 'LoadLibrary')
# ('436490000', 'LoadLibrary')
# ('437820000', 'RegQueryValue')
# ('437860000', 'RegQueryValue')
# ('437860000', 'RegQueryValue')
# ('437900000', 'RegQueryValue')
# ('437910000', 'RegQueryValue')
# ('437980000', 'RegQueryValue')
# ('437980000', 'RegQueryValue')
# ('437990000', 'RegQueryValue')
# ('437990000', 'RegQueryValue')
# ('438090000', 'RegQueryValue')
# ('438090000', 'RegQueryValue')
# ('438100000', 'RegQueryValue')
# ('438100000', 'RegQueryValue')
# ('438120000', 'RegQueryValue')
# ('438120000', 'RegQueryValue')
# ('438140000', 'RegQueryValue')
# ('438140000', 'RegQueryValue')
# ('438150000', 'RegQueryValue')
# ('438160000', 'RegQueryValue')
# ('438170000', 'RegQueryValue')
# ('438170000', 'RegQueryValue')
# ('438180000', 'RegQueryValue')
# ('438190000', 'RegQueryValue')
# ('438200000', 'RegQueryValue')
# ('438200000', 'RegQueryValue')
# ('438210000', 'RegQueryValue')
# ('438210000', 'RegQueryValue')
# ('438220000', 'RegQueryValue')
# ('438230000', 'RegQueryValue')
# ('438240000', 'RegQueryValue')
# ('438240000', 'RegQueryValue')
# ('438250000', 'RegQueryValue')
# ('438260000', 'RegQueryValue')
# ('438260000', 'RegQueryValue')
# ('438270000', 'RegQueryValue')
# ('438280000', 'RegQueryValue')
# ('438280000', 'RegQueryValue')
# ('438290000', 'RegQueryValue')
# ('438290000', 'RegQueryValue')
# ('438290000', 'RegQueryValue')
# ('438290000', 'RegQueryValue')
# ('438300000', 'RegQueryValue')
# ('438300000', 'RegQueryValue')
# ('438310000', 'RegQueryValue')
# ('438320000', 'RegQueryValue')
# ('438320000', 'RegQueryValue')
# ('438320000', 'RegQueryValue')
# ('438330000', 'RegQueryValue')
# ('438330000', 'RegQueryValue')
# ('438330000', 'RegQueryValue')
# ('438330000', 'RegQueryValue')
# ('438330000', 'RegQueryValue')
# ('438340000', 'RegQueryValue')
# ('438340000', 'RegQueryValue')
# ('438350000', 'RegQueryValue')
# ('438350000', 'RegQueryValue')
# ('438350000', 'RegQueryValue')
# ('438360000', 'RegQueryValue')
# ('438360000', 'RegQueryValue')
# ('438370000', 'RegQueryValue')
# ('438370000', 'RegQueryValue')
# ('438380000', 'RegQueryValue')
# ('438420000', 'LoadLibrary')
# ('438720000', 'LoadLibrary')
# ('439270000', 'LoadLibrary')
# ('439720000', 'RegQueryValue')
# ('439750000', 'LoadLibrary')
# ('440150000', 'RegQueryValue')
# ('440150000', 'RegQueryValue')
# ('440160000', 'RegQueryValue')
# ('440160000', 'RegQueryValue')
# ('440170000', 'RegQueryValue')
# ('440170000', 'RegQueryValue')
# ('440170000', 'RegQueryValue')
# ('440180000', 'RegQueryValue')
# ('440190000', 'LoadLibrary')
# ('440960000', 'LoadLibrary')
# ('441450000', 'LoadLibrary')
# ('442190000', 'RegCreateKey')
# ('442200000', 'RegQueryValue')
# ('442200000', 'RegQueryValue')
# ('442210000', 'RegQueryValue')
# ('442210000', 'RegQueryValue')
# ('442210000', 'RegQueryValue')
# ('442210000', 'RegQueryValue')
# ('442210000', 'RegQueryValue')
# ('442220000', 'RegQueryValue')
# ('442220000', 'RegQueryValue')
# ('442220000', 'RegQueryValue')
# ('442220000', 'RegQueryValue')
# ('442220000', 'RegQueryValue')
# ('442230000', 'RegQueryValue')
# ('442230000', 'RegQueryValue')
# ('442260000', 'RegQueryValue')
# ('442270000', 'RegQueryValue')
# ('442270000', 'RegQueryValue')
# ('442270000', 'RegQueryValue')
# ('442270000', 'RegQueryValue')
# ('442270000', 'RegQueryValue')
# ('442280000', 'RegQueryValue')
# ('442280000', 'RegQueryValue')
# ('442280000', 'RegQueryValue')
# ('442280000', 'RegQueryValue')
# ('442290000', 'RegQueryValue')
# ('442290000', 'RegQueryValue')
# ('442290000', 'RegQueryValue')
# ('442290000', 'RegQueryValue')
# ('442330000', 'RegQueryValue')
# ('442330000', 'RegQueryValue')
# ('442330000', 'RegQueryValue')
# ('442330000', 'RegQueryValue')
# ('442340000', 'RegQueryValue')
# ('442340000', 'RegQueryValue')
# ('442340000', 'RegQueryValue')
# ('442340000', 'RegQueryValue')
# ('442350000', 'RegQueryValue')
# ('442350000', 'RegQueryValue')
# ('442350000', 'RegQueryValue')
# ('442350000', 'RegQueryValue')
# ('442350000', 'RegQueryValue')
# ('442390000', 'RegQueryValue')
# ('442390000', 'RegQueryValue')
# ('442390000', 'RegQueryValue')
# ('442400000', 'RegQueryValue')
# ('442400000', 'RegQueryValue')
# ('442410000', 'RegQueryValue')
# ('442410000', 'RegQueryValue')
# ('442610000', 'RegCreateKey')
# ('442620000', 'RegQueryValue')
# ('442620000', 'RegQueryValue')
# ('442800000', 'RegCreateKey')
# ('442810000', 'RegQueryValue')
# ('442840000', 'RegQueryValue')
# ('442860000', 'RegQueryValue')
# ('443150000', 'RegQueryValue')
# ('443150000', 'RegQueryValue')
# ('443150000', 'LoadLibrary')
# ('443590000', 'LoadLibrary')
# ('447250000', 'LoadLibrary')
# ('447900000', 'RegQueryValue')
# ('447930000', 'CreateFile')
# ('448380000', 'RegQueryValue')
# ('448440000', 'LoadLibrary')
# ('448770000', 'RegQueryValue')
# ('448820000', 'RegQueryValue')
# ('448820000', 'LoadLibrary')
# ('448880000', 'RegQueryValue')
# ('448890000', 'RegQueryValue')
# ('448920000', 'RegQueryValue')
# ('448920000', 'RegQueryValue')
# ('448990000', 'RegQueryValue')
# ('448990000', 'RegQueryValue')
# ('449040000', 'RegQueryValue')
# ('449090000', 'RegQueryValue')
# ('449090000', 'RegCreateKey')
# ('449100000', 'RegQueryValue')
# ('449150000', 'RegQueryValue')
# ('449170000', 'RegQueryValue')
# ('449180000', 'RegQueryValue')
# ('449180000', 'RegQueryValue')
# ('449190000', 'RegQueryValue')
# ('449190000', 'RegQueryValue')
# ('449190000', 'RegQueryValue')
# ('449200000', 'RegCreateKey')
# ('449200000', 'RegQueryValue')
# ('449200000', 'RegQueryValue')
# ('449350000', 'RegQueryValue')
# ('449370000', 'RegQueryValue')
# ('449390000', 'LoadLibrary')
# ('449610000', 'LoadLibrary')
# ('451350000', 'RegEnumValue')
# ('451380000', 'RegEnumValue')
# ('451380000', 'RegEnumValue')
# ('451380000', 'RegEnumValue')
# ('451390000', 'RegEnumValue')
# ('451390000', 'RegEnumValue')
# ('451400000', 'RegEnumValue')
# ('451400000', 'RegEnumValue')
# ('451410000', 'RegEnumValue')
# ('451450000', 'RegEnumValue')
# ('451450000', 'LoadLibrary')
# ('451550000', 'LoadLibrary')
# ('451630000', 'RegQueryValue')
# ('451660000', 'RegQueryValue')
# ('451700000', 'RegQueryValue')
# ('451970000', 'LoadLibrary')
# ('452990000', 'LoadLibrary')
# ('453330000', 'LoadLibrary')
# ('453440000', 'LoadLibrary')
# ('461610000', 'LoadLibrary')
# ('462070000', 'LoadLibrary')
# ('462500000', 'RegQueryValue')
# ('462510000', 'RegQueryValue')
# ('462690000', 'RegQueryValue')
# ('462700000', 'LoadLibrary')
# ('463500000', 'LoadLibrary')
# ('466020000', 'RegQueryValue')
# ('466580000', 'LoadLibrary')
# ('466680000', 'RegQueryValue')
# ('466690000', 'RegQueryValue')
# ('466710000', 'LoadLibrary')
# ('467720000', 'LoadLibrary')
# ('468230000', 'RegCreateKey')
# ('468230000', 'RegQueryValue')
# ('468390000', 'RegQueryValue')
# ('468390000', 'RegQueryValue')
# ('468390000', 'RegQueryValue')
# ('468390000', 'RegQueryValue')
# ('468390000', 'RegQueryValue')
# ('468400000', 'RegQueryValue')
# ('468450000', 'RegQueryValue')
# ('468450000', 'RegQueryValue')
# ('468450000', 'RegQueryValue')
# ('468460000', 'RegQueryValue')
# ('468460000', 'RegQueryValue')
# ('468460000', 'RegQueryValue')
# ('468800000', 'RegQueryValue')
# ('469920000', 'LoadLibrary')
# ('471200000', 'CreateFile')
# ('472320000', 'LoadLibrary')
# ('472420000', 'RegQueryValue')
# ('472440000', 'LoadLibrary')
# ('472500000', 'RegCreateKey')
# ('472510000', 'RegQueryValue')
# ('472510000', 'LoadLibrary')
# ('474740000', 'RegQueryValue')
# ('474820000', 'RegQueryValue')
# ('474840000', 'RegQueryValue')
# ('475390000', 'RegQueryValue')
# ('475400000', 'RegQueryValue')
# ('475580000', 'RegQueryValue')
# ('475590000', 'RegQueryValue')
# ('475590000', 'RegQueryValue')
# ('475670000', 'RegQueryValue')
# ('475890000', 'RegQueryValue')
# ('475970000', 'RegQueryValue')
# ('476030000', 'RegEnumValue')
# ('476030000', 'RegEnumValue')
# ('476040000', 'RegEnumValue')
# ('476040000', 'RegEnumValue')
# ('476090000', 'RegEnumValue')
# ('476140000', 'RegEnumValue')
# ('476160000', 'RegEnumValue')
# ('476210000', 'RegEnumValue')
# ('476260000', 'RegEnumValue')
# ('476350000', 'RegEnumValue')
# ('476380000', 'RegEnumValue')
# ('476470000', 'RegEnumValue')
# ('476470000', 'RegEnumValue')
# ('476470000', 'RegEnumValue')
# ('476640000', 'RegEnumValue')
# ('476830000', 'RegEnumValue')
# ('476930000', 'RegEnumValue')
# ('476940000', 'RegEnumValue')
# ('476940000', 'RegEnumValue')
# ('476940000', 'RegEnumValue')
# ('476940000', 'RegEnumValue')
# ('476940000', 'RegEnumValue')
# ('476940000', 'RegEnumValue')
# ('476940000', 'RegEnumValue')
# ('476940000', 'RegEnumValue')
# ('477110000', 'RegEnumValue')
# ('477410000', 'RegQueryValue')
# ('477490000', 'RegQueryValue')
# ('477590000', 'RegQueryValue')
# ('477690000', 'RegQueryValue')
# ('478270000', 'LoadLibrary')
# ('479180000', 'RegQueryValue')
# ('479310000', 'RegCreateKey')
# ('479310000', 'RegQueryValue')
# ('479320000', 'CreateFile')
# ('479370000', 'RegEnumValue')
# ('479380000', 'RegEnumValue')
# ('479380000', 'RegEnumValue')
# ('479620000', 'RegEnumValue')
# ('479940000', 'RegEnumValue')
# ('480140000', 'RegEnumValue')
# ('480220000', 'RegEnumValue')
# ('480340000', 'RegEnumValue')
# ('480470000', 'RegEnumValue')
# ('480600000', 'RegEnumValue')
# ('480710000', 'RegEnumValue')
# ('480840000', 'RegEnumValue')
# ('480840000', 'RegEnumValue')
# ('480840000', 'RegEnumValue')
# ('480840000', 'RegEnumValue')
# ('480840000', 'RegEnumValue')
# ('480840000', 'RegEnumValue')
# ('480840000', 'RegEnumValue')
# ('481080000', 'RegCreateKey')
# ('481080000', 'RegSetValue')
# ('481270000', 'RegCreateKey')
# ('481270000', 'RegQueryValue')
# ('481410000', 'RegQueryValue')
# ('481470000', 'RegQueryValue')
# ('481530000', 'RegEnumValue')
# ('481540000', 'RegEnumValue')
# ('481540000', 'RegEnumValue')
# ('481540000', 'RegEnumValue')
# ('481590000', 'RegEnumValue')
# ('481640000', 'RegEnumValue')
# ('481660000', 'RegEnumValue')
# ('481720000', 'RegEnumValue')
# ('481770000', 'RegEnumValue')
# ('481830000', 'RegEnumValue')
# ('481960000', 'RegEnumValue')
# ('482020000', 'RegEnumValue')
# ('482020000', 'RegEnumValue')
# ('482030000', 'RegEnumValue')
# ('482140000', 'RegEnumValue')
# ('482270000', 'RegEnumValue')
# ('482390000', 'RegEnumValue')
# ('482390000', 'RegEnumValue')
# ('482390000', 'RegEnumValue')
# ('482390000', 'RegEnumValue')
# ('482390000', 'RegEnumValue')
# ('482390000', 'RegEnumValue')
# ('482400000', 'RegEnumValue')
# ('482400000', 'RegEnumValue')
# ('482400000', 'RegEnumValue')
# ('482520000', 'RegEnumValue')
# ('482830000', 'RegQueryValue')
# ('482950000', 'RegQueryValue')
# ('483030000', 'RegQueryValue')
# ('483140000', 'RegQueryValue')
# ('483830000', 'RegQueryValue')
# ('484030000', 'RegCreateKey')
# ('484070000', 'RegQueryValue')
# ('484080000', 'CreateFile')
# ('484130000', 'RegEnumValue')
# ('484130000', 'RegEnumValue')
# ('484140000', 'RegEnumValue')
# ('484390000', 'RegEnumValue')
# ('484650000', 'RegEnumValue')
# ('484770000', 'RegEnumValue')
# ('485020000', 'RegEnumValue')
# ('485100000', 'RegEnumValue')
# ('485270000', 'RegEnumValue')
# ('485410000', 'RegEnumValue')
# ('485520000', 'RegEnumValue')
# ('485650000', 'RegEnumValue')
# ('485650000', 'RegEnumValue')
# ('485660000', 'RegEnumValue')
# ('485660000', 'RegEnumValue')
# ('485660000', 'RegEnumValue')
# ('485660000', 'RegEnumValue')
# ('485660000', 'RegEnumValue')
# ('485840000', 'RegCreateKey')
# ('485850000', 'RegSetValue')
# ('486030000', 'RegCreateKey')
# ('486030000', 'RegSetValue')
# ('486080000', 'RegQueryValue')
# ('486090000', 'RegQueryValue')
# ('486090000', 'RegQueryValue')
# ('486090000', 'RegQueryValue')
# ('486100000', 'RegCreateKey')
# ('486100000', 'RegQueryValue')
# ('486110000', 'RegQueryValue')
# ('486180000', 'RegCreateKey')
# ('486180000', 'RegQueryValue')
# ('486180000', 'RegQueryValue')
# ('486190000', 'RegCreateKey')
# ('486190000', 'RegSetValue')
# ('486200000', 'RegDeleteKey')
# ('486200000', 'RegDeleteKey')
# ('486200000', 'RegDeleteKey')
# ('486260000', 'RegCreateKey')
# ('486290000', 'RegSetValue')
# ('486300000', 'RegCreateKey')
# ('486300000', 'RegQueryValue')
# ('486300000', 'RegQueryValue')
# ('486310000', 'RegCreateKey')
# ('486310000', 'RegSetValue')
# ('486510000', 'LoadLibrary')
# ('486720000', 'RegQueryValue')
# ('487080000', 'RegQueryValue')
# ('487260000', 'RegQueryValue')
# ('487270000', 'RegSetValue')
# ('487340000', 'RegSetValue')
# ('487340000', 'RegSetValue')
# ('487460000', 'RegQueryValue')
# ('487650000', 'RegQueryValue')
# ('487850000', 'RegQueryValue')
# ('488210000', 'RegQueryValue')
# ('488400000', 'RegQueryValue')
# ('488410000', 'RegSetValue')
# ('488410000', 'RegSetValue')
# ('488410000', 'RegSetValue')
# ('488600000', 'RegQueryValue')
# ('488800000', 'RegQueryValue')
# ('489030000', 'RegQueryValue')
# ('489450000', 'RegQueryValue')
# ('489450000', 'RegQueryValue')
# ('489470000', 'RegQueryValue')
# ('489570000', 'RegQueryValue')
# ('490690000', 'RegQueryValue')
# ('491000000', 'RegQueryValue')
# ('491270000', 'RegQueryValue')
# ('491430000', 'RegQueryValue')
# ('492120000', 'RegQueryValue')
# ('492310000', 'CreateFile')
# ('492310000', 'CreateFile')
# ('492880000', 'RegQueryValue')
# ('493140000', 'RegQueryValue')
# ('493210000', 'LoadLibrary')
# ('493490000', 'RegQueryValue')
# ('493550000', 'RegQueryValue')
# ('493750000', 'RegQueryValue')
# ('493910000', 'RegQueryValue')
# ('494140000', 'RegQueryValue')
# ('494210000', 'RegQueryValue')
# ('494270000', 'RegQueryValue')
# ('494410000', 'RegQueryValue')
# ('494530000', 'RegQueryValue')
# ('494700000', 'RegQueryValue')
# ('494850000', 'RegQueryValue')
# ('497720000', 'RegQueryValue')
# ('497990000', 'RegQueryValue')
# ('498010000', 'RegQueryValue')
# ('498040000', 'RegQueryValue')
# ('498480000', 'RegQueryValue')
# ('498980000', 'CreateFile')
# ('499320000', 'LoadLibrary')
# ('499880000', 'RegQueryValue')
# ('499900000', 'LoadLibrary')
# ('500100000', 'RegQueryValue')
# ('500120000', 'RegQueryValue')
# ('500150000', 'RegQueryValue')
# ('500250000', 'RegQueryValue')
# ('500310000', 'RegQueryValue')
# ('500410000', 'RegQueryValue')
# ('500490000', 'RegQueryValue')
# ('500600000', 'RegQueryValue')
# ('500690000', 'RegQueryValue')
# ('500760000', 'RegQueryValue')
# ('500760000', 'RegQueryValue')
# ('500760000', 'RegQueryValue')
# ('500820000', 'RegQueryValue')
# ('501050000', 'RegQueryValue')
# ('501090000', 'RegQueryValue')
# ('501410000', 'RegQueryValue')
# ('501420000', 'RegQueryValue')
# ('501520000', 'LoadLibrary')
# ('501560000', 'RegQueryValue')
# ('501560000', 'RegQueryValue')
# ('501560000', 'RegQueryValue')
# ('501570000', 'RegQueryValue')
# ('501570000', 'RegQueryValue')
# ('501570000', 'RegQueryValue')
# ('501570000', 'RegQueryValue')
# ('501580000', 'RegQueryValue')
# ('501580000', 'RegQueryValue')
# ('501580000', 'RegQueryValue')
# ('501590000', 'RegQueryValue')
# ('501590000', 'RegQueryValue')
# ('501590000', 'RegQueryValue')
# ('501590000', 'RegQueryValue')
# ('501600000', 'RegQueryValue')
# ('501600000', 'RegQueryValue')
# ('501600000', 'RegQueryValue')
# ('501600000', 'RegQueryValue')
# ('501600000', 'RegQueryValue')
# ('501610000', 'RegQueryValue')
# ('501610000', 'RegQueryValue')
# ('501620000', 'RegQueryValue')
# ('501620000', 'RegQueryValue')
# ('501660000', 'RegQueryValue')
# ('501660000', 'RegQueryValue')
# ('501660000', 'RegQueryValue')
# ('501670000', 'RegQueryValue')
# ('501670000', 'RegQueryValue')
# ('501670000', 'RegQueryValue')
# ('501710000', 'RegQueryValue')
# ('501710000', 'RegQueryValue')
# ('501720000', 'RegQueryValue')
# ('501720000', 'RegQueryValue')
# ('501730000', 'RegQueryValue')
# ('501730000', 'RegQueryValue')
# ('501730000', 'RegQueryValue')
# ('501770000', 'RegQueryValue')
# ('501780000', 'RegQueryValue')
# ('501780000', 'RegQueryValue')
# ('501780000', 'RegQueryValue')
# ('501790000', 'RegQueryValue')
# ('501800000', 'RegQueryValue')
# ('501860000', 'RegQueryValue')
# ('501890000', 'RegQueryValue')
# ('501890000', 'RegQueryValue')
# ('501900000', 'RegQueryValue')
# ('501910000', 'RegQueryValue')
# ('501980000', 'RegEnumValue')
# ('501980000', 'RegEnumValue')
# ('502500000', 'LoadLibrary')
# ('502780000', 'CreateFile')
# ('502780000', 'CreateFile')
# ('503060000', 'RegQueryValue')
# ('503130000', 'RegQueryValue')
# ('503180000', 'RegQueryValue')
# ('503370000', 'RegQueryValue')
# ('503460000', 'RegQueryValue')
# ('503730000', 'RegQueryValue')
# ('503860000', 'RegQueryValue')
# ('504130000', 'RegQueryValue')
# ('504250000', 'RegQueryValue')
# ('504280000', 'RegQueryValue')
# ('504290000', 'RegQueryValue')
# ('504310000', 'RegQueryValue')
# ('504330000', 'RegQueryValue')
# ('504340000', 'RegQueryValue')
# ('504790000', 'LoadLibrary')
# ('505050000', 'RegQueryValue')
# ('505050000', 'RegQueryValue')
# ('505050000', 'RegQueryValue')
# ('505850000', 'RegQueryValue')
# ('506070000', 'RegQueryValue')
# ('506270000', 'RegQueryValue')
# ('506280000', 'RegQueryValue')
# ('506820000', 'RegQueryValue')
# ('506860000', 'RegQueryValue')
# ('506950000', 'RegQueryValue')
# ('507020000', 'RegQueryValue')
# ('507110000', 'RegQueryValue')
# ('507210000', 'RegQueryValue')
# ('508400000', 'RegQueryValue')
# ('508520000', 'RegQueryValue')
# ('508760000', 'RegQueryValue')
# ('509150000', 'LoadLibrary')
# ('509780000', 'LoadLibrary')
# ('510810000', 'RegQueryValue')
# ('510840000', 'RegQueryValue')
# ('510930000', 'RegQueryValue')
# ('511020000', 'RegQueryValue')
# ('511130000', 'RegQueryValue')
# ('511200000', 'RegQueryValue')
# ('512860000', 'LoadLibrary')
# ('512970000', 'RegQueryValue')
# ('513050000', 'RegQueryValue')
# ('513410000', 'RegQueryValue')
# ('513830000', 'LoadLibrary')
# ('513880000', 'RegQueryValue')
# ('513960000', 'RegQueryValue')
# ('513980000', 'RegQueryValue')
# ('514020000', 'RegQueryValue')
# ('517440000', 'LoadLibrary')
# ('519590000', 'RegQueryValue')
# ('519590000', 'RegQueryValue')
# ('519670000', 'RegQueryValue')
# ('520080000', 'RegQueryValue')
# ('520080000', 'RegQueryValue')
# ('520080000', 'RegQueryValue')
# ('520080000', 'RegQueryValue')
# ('520090000', 'RegQueryValue')
# ('520090000', 'RegQueryValue')
# ('520320000', 'RegQueryValue')
# ('520490000', 'RegQueryValue')
# ('521490000', 'CreateFile')
# ('521490000', 'CreateFile')
# ('521750000', 'CreateFile')
# ('521760000', 'CreateFile')
# ('522830000', 'RegQueryValue')
# ('522830000', 'RegQueryValue')
# ('522880000', 'RegQueryValue')
# ('523360000', 'CreateFile')
# ('528050000', 'LoadLibrary')
# ('560770000', 'LoadLibrary')
# ('561910000', 'CreateFile')
# ('562310000', 'RegQueryValue')
# ('562310000', 'RegEnumValue')
# ('562320000', 'RegEnumValue')
# ('562330000', 'RegEnumValue')
# ('562370000', 'RegEnumValue')
# ('577580000', 'RegQueryValue')
# ('577580000', 'RegQueryValue')
# ('577590000', 'RegQueryValue')
# ('577730000', 'RegQueryValue')
# ('577730000', 'RegQueryValue')
# ('577730000', 'RegQueryValue')
# ('577730000', 'RegQueryValue')
# ('577730000', 'RegQueryValue')
# ('577730000', 'RegQueryValue')
# ('578080000', 'RegQueryValue')
# ('578250000', 'RegQueryValue')
# ('578290000', 'RegQueryValue')
# ('578290000', 'RegQueryValue')
# ('578320000', 'RegQueryValue')
# ('657310000', 'LoadLibrary')
# ('657950000', 'RegQueryValue')
# ('666790000', 'RegCreateKey')
# ('666880000', 'RegQueryValue')
# ('668570000', 'CreateFile')
# ('668580000', 'CreateFile')
# ('668600000', 'CreateFile')
# ('668600000', 'CreateFile')
# ('669950000', 'CreateFile')
# ('669950000', 'CreateFile')
# ('669970000', 'CreateFile')
# ('669970000', 'CreateFile')
# ('670100000', 'DeleteFile')
# ('670100000', 'DeleteFile')
# ('673470000', 'CreateFile')
# ('673470000', 'CreateFile')
# ('673490000', 'CreateFile')
# ('673490000', 'CreateFile')
# ('673710000', 'DeleteFile')
# ('673710000', 'DeleteFile')
# ('682160000', 'RegQueryValue')
# ('682690000', 'CreateFile')
# ('682780000', 'RegQueryValue')
# ('682850000', 'RegQueryValue')
# ('682880000', 'RegQueryValue')
# ('682910000', 'RegQueryValue')
# ('683030000', 'RegQueryValue')
# ('683040000', 'RegQueryValue')
# ('683070000', 'RegQueryValue')
# ('683150000', 'RegQueryValue')
# ('683210000', 'RegQueryValue')
# ('683310000', 'RegQueryValue')
# ('683380000', 'RegQueryValue')
# ('686050000', 'RegQueryValue')
# ('686060000', 'RegQueryValue')
# ('686180000', 'RegQueryValue')
# ('686330000', 'RegQueryValue')
# ('686350000', 'CreateFile')
# ('686550000', 'RegQueryValue')
# ('686570000', 'CreateFile')
# ('688980000', 'CreateFile')
# ('688980000', 'CreateFile')
# ('689000000', 'CreateFile')
# ('689000000', 'CreateFile')
# ('689230000', 'DeleteFile')
# ('689230000', 'DeleteFile')
# ('699150000', 'RegQueryValue')
# ('699150000', 'RegQueryValue')
# ('699170000', 'RegQueryValue')
# ('699390000', 'RegQueryValue')
# ('699390000', 'RegQueryValue')
# ('699390000', 'RegQueryValue')
# ('699390000', 'RegQueryValue')
# ('699390000', 'RegQueryValue')
# ('699390000', 'RegQueryValue')
# ('699630000', 'RegQueryValue')
# ('700230000', 'RegQueryValue')
# ('701770000', 'CreateFile')
# ('701770000', 'CreateFile')
# ('701790000', 'CreateFile')
# ('701790000', 'CreateFile')
# ('702010000', 'DeleteFile')
# ('702010000', 'DeleteFile')
# ('703260000', 'CreateFile')
# ('703260000', 'CreateFile')
# ('703280000', 'CreateFile')
# ('703280000', 'CreateFile')
# ('703500000', 'DeleteFile')
# ('703500000', 'DeleteFile')
# ('706690000', 'CreateFile')
# ('706690000', 'CreateFile')
# ('706710000', 'CreateFile')
# ('706710000', 'CreateFile')
# ('706930000', 'DeleteFile')
# ('706930000', 'DeleteFile')
# ('724870000', 'LoadLibrary')
# ('724940000', 'RegQueryValue')
# ('724960000', 'RegQueryValue')
# ('724990000', 'RegQueryValue')
# ('725020000', 'RegQueryValue')
# ('725070000', 'RegQueryValue')
# ('725090000', 'RegQueryValue')
# ('725120000', 'RegQueryValue')
# ('725210000', 'LoadLibrary')
# ('725550000', 'RegQueryValue')
# ('725560000', 'RegQueryValue')
# ('725560000', 'RegQueryValue')
# ('725560000', 'RegQueryValue')
# ('725570000', 'RegQueryValue')
# ('725570000', 'RegQueryValue')
# ('725600000', 'RegQueryValue')
# ('725600000', 'RegQueryValue')
# ('725610000', 'RegQueryValue')
# ('725610000', 'RegQueryValue')
# ('725610000', 'RegQueryValue')
# ('725620000', 'RegQueryValue')
# ('725620000', 'RegQueryValue')
# ('725640000', 'RegQueryValue')
# ('725660000', 'RegQueryValue')
# ('725670000', 'RegQueryValue')
# ('725820000', 'CreateFile')
# ('726080000', 'CreateFile')
# ('726110000', 'RegQueryValue')
# ('726120000', 'RegQueryValue')
# ('726160000', 'CreateFile')
# ('726180000', 'RegQueryValue')
# ('726190000', 'RegQueryValue')
# ('726210000', 'CreateFile')
# ('726230000', 'CreateFile')
# ('726240000', 'RegCreateKey')
# ('726250000', 'RegSetValue')
# ('726250000', 'CreateFile')
# ('726270000', 'CreateFile')
# ('726280000', 'RegCreateKey')
# ('726290000', 'RegSetValue')
# ('726300000', 'RegQueryValue')
# ('726340000', 'RegQueryValue')
# ('726450000', 'RegQueryValue')
# ('726460000', 'RegQueryValue')
# ('726460000', 'RegQueryValue')
# ('726480000', 'RegQueryValue')
# ('726500000', 'RegQueryValue')
# ('726530000', 'RegQueryValue')
# ('726540000', 'RegQueryValue')
# ('726560000', 'RegQueryValue')
# ('726580000', 'RegQueryValue')
# ('726610000', 'RegQueryValue')
# ('726610000', 'RegQueryValue')
# ('726620000', 'RegQueryValue')
# ('726620000', 'RegQueryValue')
# ('726620000', 'RegQueryValue')
# ('726620000', 'RegQueryValue')
# ('726620000', 'RegQueryValue')
# ('726630000', 'RegQueryValue')
# ('726630000', 'RegQueryValue')
# ('726630000', 'RegQueryValue')
# ('726630000', 'RegQueryValue')
# ('726640000', 'RegQueryValue')
# ('726640000', 'RegQueryValue')
# ('726670000', 'RegQueryValue')
# ('726680000', 'RegQueryValue')
# ('726740000', 'RegQueryValue')
# ('726750000', 'RegQueryValue')
# ('726770000', 'RegQueryValue')
# ('726970000', 'RegQueryValue')
# ('727250000', 'RegQueryValue')
# ('727310000', 'RegQueryValue')
# ('727320000', 'RegQueryValue')
# ('727380000', 'RegQueryValue')
# ('727390000', 'RegQueryValue')
# ('727410000', 'RegQueryValue')
# ('727490000', 'RegQueryValue')
# ('727520000', 'RegQueryValue')
# ('727540000', 'RegCreateKey')
# ('727550000', 'RegQueryValue')
# ('727550000', 'RegCreateKey')
# ('727550000', 'RegQueryValue')
# ('727570000', 'RegQueryValue')
# ('727590000', 'RegCreateKey')
# ('727600000', 'RegQueryValue')
# ('727600000', 'RegCreateKey')
# ('727600000', 'RegQueryValue')
# ('727690000', 'RegQueryValue')
# ('727720000', 'RegQueryValue')
# ('727800000', 'RegQueryValue')
# ('727870000', 'RegQueryValue')
# ('727950000', 'RegQueryValue')
# ('728030000', 'RegQueryValue')
# ('728470000', 'RegQueryValue')
# ('728540000', 'RegQueryValue')
# ('728590000', 'RegQueryValue')
# ('728630000', 'RegCreateKey')
# ('728680000', 'RegSetValue')
# ('728690000', 'RegSetValue')
# ('728700000', 'RegSetValue')
# ('728700000', 'RegSetValue')
# ('728730000', 'RegQueryValue')
# ('728730000', 'RegQueryValue')
# ('728740000', 'RegQueryValue')
# ('728750000', 'RegQueryValue')
# ('728750000', 'RegQueryValue')
# ('728770000', 'RegQueryValue')
# ('728780000', 'RegQueryValue')
# ('728790000', 'RegQueryValue')
# ('728790000', 'RegQueryValue')
# ('728800000', 'RegQueryValue')
# ('728820000', 'RegQueryValue')
# ('728830000', 'RegQueryValue')
# ('728860000', 'RegSetValue')
# ('728870000', 'RegSetValue')
# ('728900000', 'RegQueryValue')
# ('728910000', 'RegQueryValue')
# ('728910000', 'RegQueryValue')
# ('728980000', 'OpenProcess')
# ('728980000', 'OpenProcess')
# ('729170000', 'RegDeleteKey')
# ('729210000', 'RegQueryValue')
# ('729220000', 'RegQueryValue')
# ('729230000', 'RegQueryValue')
# ('729250000', 'RegQueryValue')
# ('729260000', 'RegQueryValue')
# ('729270000', 'RegQueryValue')
# ('729350000', 'DeleteFile')
# ('729350000', 'DeleteFile')
# ('729420000', 'OpenProcess')
# ('729420000', 'OpenProcess')
# ('729460000', 'OpenProcess')
# ('729460000', 'OpenProcess')
# ('729510000', 'RegDeleteKey')
# ('729550000', 'RegQueryValue')
# ('729570000', 'RegQueryValue')
# ('729570000', 'RegQueryValue')
# ('729650000', 'DeleteFile')
# ('729650000', 'DeleteFile')
# ('729720000', 'OpenProcess')
# ('729720000', 'OpenProcess')
# ('729760000', 'OpenProcess')
# ('729760000', 'OpenProcess')
# ('729800000', 'RegQueryValue')
# ('729800000', 'RegQueryValue')
# ('729810000', 'RegQueryValue')
# ('729820000', 'RegQueryValue')
# ('729820000', 'RegQueryValue')
# ('729870000', 'RegQueryValue')
# ('730950000', 'CreateFile')
# ('730950000', 'CreateFile')
# ('730980000', 'CreateFile')
# ('730980000', 'CreateFile')
# ('731040000', 'CreateFile')
# ('731040000', 'CreateFile')
# ('731210000', 'RegQueryValue')
# ('731270000', 'RegQueryValue')
# ('731290000', 'RegQueryValue')
# ('731320000', 'RegQueryValue')
# ('731400000', 'RegQueryValue')
# ('731460000', 'RegQueryValue')
# ('731500000', 'RegQueryValue')
# ('731570000', 'OpenProcess')
# ('731570000', 'OpenProcess')
# ('731620000', 'OpenProcess')
# ('731620000', 'OpenProcess')
# ('731830000', 'OpenProcess')
# ('731840000', 'OpenProcess')
# ('731850000', 'OpenProcess')
# ('731870000', 'OpenProcess')
# ('731900000', 'OpenProcess')
# ('731900000', 'OpenProcess')
# ('732330000', 'RegQueryValue')
# ('732700000', 'RegQueryValue')
# ('732710000', 'RegQueryValue')
# ('733230000', 'RegQueryValue')
# ('733230000', 'RegQueryValue')
# ('733250000', 'RegQueryValue')
# ('733510000', 'RegQueryValue')
# ('733540000', 'RegQueryValue')
# ('733540000', 'LoadLibrary')
# ('733660000', 'RegQueryValue')

# %%
# output
import pickle

out_hl_list = hl_list
out_tag = in_tag
with open(out_picklefile, 'wb') as o:
    pickle.dump(out_hl_list, o)

# %%
# output 2
with open(out_csvfile, 'wb') as o:
    o.write(b"hooklog\n")
    for h in hl_list:
        o.write(h.encode("ascii") + b"\n")

# %%
# output 3
total_api_set = set()
for file in hl_list:
    hl3 = Hooklog(file, in_parseFirstPar)
    total_api_set.update(hl3.getWinSet(in_window))

with open(out_featuretabfile, 'wb') as o:
    o.write(b"hooklog")
    for api in total_api_set:
        o.write(b"\t" + api.encode("ascii"))
    o.write(b"\n")
    
    for h in hl_list:
        hl3 = Hooklog(h, in_parseFirstPar)
        hl3_set = hl3.getWinSet(in_window)
        o.write(hl3.digitname.encode("ascii"))
        for api in total_api_set:
            if api in hl3_set:
                o.write(b"\tTrue")
            else:
                o.write(b"\tFalse")
        o.write(b"\n")

# %%
# output 4
# count api freq
freq_dict = dict()
for file in hl_list:
    hl3 = Hooklog(file, in_parseFirstPar)
    for i in hl3.li:
        if i[1] not in freq_dict:
            freq_dict[i[1]] = 1
        else:
            freq_dict[i[1]] += 1

print(freq_dict)

import pickle
with open(out_apifreq_pk, 'wb') as o:
    pickle.dump(freq_dict, o)
# Out:
# {'CreateFile': 1301, 'RegQueryValue': 15678, 'LoadLibrary': 1915, 'RegCreateKey': 794, 'RegEnumValue': 1526, 'RegSetValue': 616, 'RegDeleteKey': 64, 'DeleteFile': 204, 'OpenProcess': 518, 'CreateProcessInternal': 14, 'CreateProcess': 12}
